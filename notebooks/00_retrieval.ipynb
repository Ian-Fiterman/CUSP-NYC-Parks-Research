# %%
import deweydatapy as ddp

# =========================================================
# 1. CONFIGURATION
# =========================================================
API_KEY = "akv1_AdhTn-cf6cfXAaZlTX1XHkR85BPPO8QpZQL"
API_URL = "https://api.deweydata.io/api/v1/external/data/prj_7bo6mzzr__cdst_bmwdcnko7jajm7rb"

START_DATE = '2022-04-01'
END_DATE   = '2022-06-30'

DATA_DIR = "../data/raw/advan"

# %%
# =========================================================
# 2. METADATA
# =========================================================
print("Fetching metadata...")
meta = ddp.get_meta(API_KEY, API_URL, print_meta=True)
# Out:
# Fetching metadata...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Program Files\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
# ...

# %%
# =========================================================
# 3. FILE LIST
# =========================================================
print(f"\nFetching file list from {START_DATE} to {END_DATE}...")
files_df = ddp.get_file_list(API_KEY, API_URL,
                             start_date=START_DATE,
                             end_date=END_DATE,
                             print_info=True)

if files_df.empty:
    print("No files found for the given date range. Exiting.")
    exit()
# Out:
# ...
# Files information collection completed.
#
# Files information summary ---------------------------------------
# Total number of pages: 1
# Total number of files: 3
# Total files size (MB): 35.67
# Average single file size (MB): 11.89
# Date partition column: DATE_RANGE_START
# Expires at: 2026-02-07T16:46:55.327279+00:00
# -----------------------------------------------------------------

# %%
# =========================================================
# 4. SAMPLE PREVIEW
# =========================================================
print("\nPreviewing first file sample...")
sample_url = files_df['link'].iloc[0]
sample_df = ddp.read_sample(sample_url, nrows=100)
print(sample_df[['LOCATION_NAME', 'NAICS_CODE']].head())
# Out:
#                    LOCATION_NAME  NAICS_CODE
# 0                     Cohen Park      712190
# 1         Golden Hill State Park      712190
# 2            Point Gratiot Beach      712190
# 3               Mead Square Park      712190
# 4  Fire Island National Seashore      712190

# %%
# =========================================================
# 5. DOWNLOAD
# =========================================================
print(f"\nFound {len(files_df)} files. Starting download to: {DATA_DIR}")
ddp.download_files(files_df, DATA_DIR)
print("Download complete.")
# Out:
# Found 3 files. Starting download...
# ...
# Writing ../data/Advan/2022-04--data_01c238ce-0307-b001-0042-fa0705e531da_906_6_0.csv.gz
# Please be patient. It may take a while...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 10
#       6 print(f"Found {len(files_df)} files. Starting download...")
#       8 # 4. Download the files to the data directory
#       9 # 'slice_files=True' is recommended for large datasets to handle chunks
# ---> 10 ddp.download_files(files_df, data_dir)
#      12 print(f"Download complete. Files are located in: {data_dir}")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\deweydatapy\download.py:335, in download_files(files_df, dest_folder, filename_prefix, skip_exists)
#     332 print("Please be patient. It may take a while...")
#     333 sys.stdout.flush()
# --> 335 response = requests.get(files_df['link'][i])
# ...
